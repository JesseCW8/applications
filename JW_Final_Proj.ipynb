# %%
#import libraries
import requests
from datetime import datetime as dt
from datetime import timedelta
import pandas as pd

# %%
# get events from n days ago
iso = 760 #Look in ACLED documentation ISO code for number this is for Niger
limit = 400

api_url = 'https://api.acleddata.com/acled/read?terms=accept&iso={}'.format(iso)
print (api_url, type(api_url)) #creates request according to ACLED format specifications - p. 13
# Out:
# https://api.acleddata.com/acled/read?terms=accept&iso=760 <class 'str'>

# %%
response = requests.get(api_url)
data = response.json()
data.keys()
data['count']
# Out:
# 500

# %% [markdown]
# ### From the documentation we know this is the max return --- How can we get all the results?

# %%
# Let's mkae a function that updates our search to get the new pages

def ping_acled(api_url): 
    '''
    Takes one parameter search term for API
    '''
    
    response = requests.get(api_url)
    data = response.json()
    return data

# %%
results = [] # empty data strcture to store results
num_results = 500 # condition to continue adding pages
count = 0  # tracker of results
page = 1 #Per the documentation each page will give us more results

while num_results == 500: #if less 500 or 0 we know we have all the results
    print ("starting ", page, " ", num_results) #just to see our progress
    api_url = 'https://api.acleddata.com/acled/read?terms=accept&iso={}&page={}'.format(iso,page) #the search
    data = ping_acled(api_url) #call the previous function 
    results.append(data['data']) #store in our results
    count += data['count'] #Track number of results
    num_results = data['count'] #update our condition
    page += 1 #update our page variable
    print ("Total Results ", count) #Track our progress
# Out:
# starting  1   500
# Total Results  500
# starting  2   500
# Total Results  1000
# starting  3   500
# Total Results  1500
# starting  4   500
# Total Results  2000
# starting  5   500
# Total Results  2500
# starting  6   500
# Total Results  3000
# starting  7   500
# Total Results  3500
# starting  8   500
# Total Results  4000
# starting  9   500
# Total Results  4500
# starting  10   500
# Total Results  5000
# starting  11   500
# Total Results  5500
# starting  12   500
# Total Results  6000
# starting  13   500
# Total Results  6500
# starting  14   500
# Total Results  7000
# starting  15   500
# Total Results  7500
# starting  16   500
# Total Results  8000
# starting  17   500
# Total Results  8500
# starting  18   500
# Total Results  9000
# starting  19   500
# Total Results  9500
# starting  20   500
# Total Results  10000
# starting  21   500
# Total Results  10500
# starting  22   500
# Total Results  11000
# starting  23   500
# Total Results  11500
# starting  24   500
# Total Results  12000
# starting  25   500
# Total Results  12500
# starting  26   500
# Total Results  13000
# starting  27   500
# Total Results  13500
# starting  28   500
# Total Results  14000
# starting  29   500
# Total Results  14500
# starting  30   500
# Total Results  15000
# starting  31   500
# Total Results  15500
# starting  32   500
# Total Results  16000
# starting  33   500
# Total Results  16500
# starting  34   500
# Total Results  17000
# starting  35   500
# Total Results  17500
# starting  36   500
# Total Results  18000
# starting  37   500
# Total Results  18500
# starting  38   500
# Total Results  19000
# starting  39   500
# Total Results  19500
# starting  40   500
# Total Results  20000
# starting  41   500
# Total Results  20500
# starting  42   500
# Total Results  21000
# starting  43   500
# Total Results  21500
# starting  44   500
# Total Results  22000
# starting  45   500
# Total Results  22500
# starting  46   500
# Total Results  23000
# starting  47   500
# Total Results  23500
# starting  48   500
# Total Results  24000
# starting  49   500
# Total Results  24500
# starting  50   500
# Total Results  25000
# starting  51   500
# Total Results  25500
# starting  52   500
# Total Results  26000
# starting  53   500
# Total Results  26500
# starting  54   500
# Total Results  27000
# starting  55   500
# Total Results  27500
# starting  56   500
# Total Results  28000
# starting  57   500
# Total Results  28500
# starting  58   500
# Total Results  29000
# starting  59   500
# Total Results  29500
# starting  60   500
# Total Results  30000
# starting  61   500
# Total Results  30500
# starting  62   500
# Total Results  31000
# starting  63   500
# Total Results  31500
# starting  64   500
# Total Results  32000
# starting  65   500
# Total Results  32500
# starting  66   500
# Total Results  33000
# starting  67   500
# Total Results  33500
# starting  68   500
# Total Results  34000
# starting  69   500
# Total Results  34500
# starting  70   500
# Total Results  35000
# starting  71   500
# Total Results  35500
# starting  72   500
# Total Results  36000
# starting  73   500
# Total Results  36500
# starting  74   500
# Total Results  37000
# starting  75   500
# Total Results  37500
# starting  76   500
# Total Results  38000
# starting  77   500
# Total Results  38500
# starting  78   500
# Total Results  39000
# starting  79   500
# Total Results  39500
# starting  80   500
# Total Results  40000
# starting  81   500
# Total Results  40500
# starting  82   500
# Total Results  41000
# starting  83   500
# Total Results  41500
# starting  84   500
# Total Results  42000
# starting  85   500
# Total Results  42500
# starting  86   500
# Total Results  43000
# starting  87   500
# Total Results  43500
# starting  88   500
# Total Results  44000
# starting  89   500
# Total Results  44500
# starting  90   500
# Total Results  45000
# starting  91   500
# Total Results  45500
# starting  92   500
# Total Results  46000
# starting  93   500
# Total Results  46500
# starting  94   500
# Total Results  47000
# starting  95   500
# Total Results  47500
# starting  96   500
# Total Results  48000
# starting  97   500
# Total Results  48500
# starting  98   500
# Total Results  49000
# starting  99   500
# Total Results  49500
# starting  100   500
# Total Results  50000
# starting  101   500
# Total Results  50500
# starting  102   500
# Total Results  51000
# starting  103   500
# Total Results  51500
# starting  104   500
# Total Results  52000
# starting  105   500
# Total Results  52500
# starting  106   500
# Total Results  53000
# starting  107   500
# Total Results  53500
# starting  108   500
# Total Results  54000
# starting  109   500
# Total Results  54500
# starting  110   500
# Total Results  55000
# starting  111   500
# Total Results  55500
# starting  112   500
# Total Results  56000
# starting  113   500
# Total Results  56500
# starting  114   500
# Total Results  57000
# starting  115   500
# Total Results  57500
# starting  116   500
# Total Results  58000
# starting  117   500
# Total Results  58500
# starting  118   500
# Total Results  59000
# starting  119   500
# Total Results  59500
# starting  120   500
# Total Results  60000
# starting  121   500
# Total Results  60500
# starting  122   500
# Total Results  61000
# starting  123   500
# Total Results  61500
# starting  124   500
# Total Results  62000
# starting  125   500
# Total Results  62500
# starting  126   500
# Total Results  63000
# starting  127   500
# Total Results  63500
# starting  128   500
# Total Results  64000
# starting  129   500
# Total Results  64500
# starting  130   500
# Total Results  65000
# starting  131   500
# Total Results  65500
# starting  132   500
# Total Results  66000
# starting  133   500
# Total Results  66500
# starting  134   500
# Total Results  67000
# starting  135   500
# Total Results  67500
# starting  136   500
# Total Results  68000
# starting  137   500
# Total Results  68500
# starting  138   500
# Total Results  69000
# starting  139   500
# Total Results  69500
# starting  140   500
# Total Results  70000
# starting  141   500
# Total Results  70500
# starting  142   500
# Total Results  71000
# starting  143   500
# Total Results  71500
# starting  144   500
# Total Results  72000
# starting  145   500
# Total Results  72500
# starting  146   500
# Total Results  73000
# starting  147   500
# Total Results  73500
# starting  148   500
# Total Results  74000
# starting  149   500
# Total Results  74500
# starting  150   500
# Total Results  75000
# starting  151   500
# Total Results  75500
# starting  152   500
# Total Results  76000
# starting  153   500
# Total Results  76500
# starting  154   500
# Total Results  77000
# starting  155   500
# Total Results  77500
# starting  156   500
# Total Results  78000
# starting  157   500
# Total Results  78500
# starting  158   500
# Total Results  79000
# starting  159   500
# Total Results  79500
# starting  160   500
# Total Results  80000
# starting  161   500
# Total Results  80500
# starting  162   500
# Total Results  81000
# starting  163   500
# Total Results  81500
# starting  164   500
# Total Results  81542

# %%
#Now I want to put them together into one giant result
super_list = []
for res in results: 
    super_list += res
    print (len(super_list))
# Out:
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000
# 4500
# 5000
# 5500
# 6000
# 6500
# 7000
# 7500
# 8000
# 8500
# 9000
# 9500
# 10000
# 10500
# 11000
# 11500
# 12000
# 12500
# 13000
# 13500
# 14000
# 14500
# 15000
# 15500
# 16000
# 16500
# 17000
# 17500
# 18000
# 18500
# 19000
# 19500
# 20000
# 20500
# 21000
# 21500
# 22000
# 22500
# 23000
# 23500
# 24000
# 24500
# 25000
# 25500
# 26000
# 26500
# 27000
# 27500
# 28000
# 28500
# 29000
# 29500
# 30000
# 30500
# 31000
# 31500
# 32000
# 32500
# 33000
# 33500
# 34000
# 34500
# 35000
# 35500
# 36000
# 36500
# 37000
# 37500
# 38000
# 38500
# 39000
# 39500
# 40000
# 40500
# 41000
# 41500
# 42000
# 42500
# 43000
# 43500
# 44000
# 44500
# 45000
# 45500
# 46000
# 46500
# 47000
# 47500
# 48000
# 48500
# 49000
# 49500
# 50000
# 50500
# 51000
# 51500
# 52000
# 52500
# 53000
# 53500
# 54000
# 54500
# 55000
# 55500
# 56000
# 56500
# 57000
# 57500
# 58000
# 58500
# 59000
# 59500
# 60000
# 60500
# 61000
# 61500
# 62000
# 62500
# 63000
# 63500
# 64000
# 64500
# 65000
# 65500
# 66000
# 66500
# 67000
# 67500
# 68000
# 68500
# 69000
# 69500
# 70000
# 70500
# 71000
# 71500
# 72000
# 72500
# 73000
# 73500
# 74000
# 74500
# 75000
# 75500
# 76000
# 76500
# 77000
# 77500
# 78000
# 78500
# 79000
# 79500
# 80000
# 80500
# 81000
# 81500
# 81542

# %%
#convert it into an pandas data frame or just use your data structure and do more stuff
syria_res = pd.DataFrame(super_list)
syria_res.head()
# Out:
#    data_id  iso event_id_cnty event_id_no_cnty  event_date  year  \
# 0  7257107  760      SYR83570            83570  2020-10-24  2020
# 1  7257111  760      SYR83538            83538  2020-10-24  2020
# 2  7257113  760      SYR83468            83468  2020-10-24  2020
# 3  7257118  760      SYR83478            83478  2020-10-24  2020
# 4  7257120  760      SYR83422            83422  2020-10-24  2020
#
#   time_precision                  event_type  \
# 0              1  Explosions/Remote violence
# 1              1  Explosions/Remote violence
# 2              1  Violence against civilians
# 3              1      Strategic developments
# 4              1                     Battles
#
#                       sub_event_type                             actor1  ...  \
# 0  Shelling/artillery/missile attack  Military Forces of Turkey (2016-)  ...
# 1  Shelling/artillery/missile attack   Military Forces of Syria (2000-)  ...
# 2                             Attack   Unidentified Armed Group (Syria)  ...
# 3           Change to group/activity  Military Forces of Russia (2000-)  ...
# 4                        Armed clash   Military Forces of Syria (2000-)  ...
#
#               location latitude longitude geo_precision source source_scale  \
# 0          Tall Refaat  36.4726   37.0941             2   SOHR        Other
# 1               Sfuhen  35.6073   36.4645             1   SOHR        Other
# 2  Kafr Naseh Elatareb  36.1359   36.7883             1   SOHR        Other
# 3             Ein Issa  36.3837   38.8628             2   SOHR        Other
# 4               Rahjan  35.4066   37.4341             2   SOHR        Other
#
#                                                notes fatalities   timestamp  \
# 0  On 24 October 2020, Turkish forces and opposit...          0  1603742175
# 1  On 24 October 2020, regime forces shelled Sfuh...          0  1603742175
# 2  On 24 October 2020, unidentified gunmen shot a...          1  1603742175
# 3  Movement of forces: On 24 October 2020, reinfo...          0  1603742175
# 4  On 24 October 2020, clashes took place regime ...          0  1603742175
#
#   iso3
# 0  SYR
# 1  SYR
# 2  SYR
# 3  SYR
# 4  SYR
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Do the right thing, take some time to look at the codebook and see what these columns are

# %%
syria_res.columns
# Out:
# Index(['data_id', 'iso', 'event_id_cnty', 'event_id_no_cnty', 'event_date',
#        'year', 'time_precision', 'event_type', 'sub_event_type', 'actor1',
#        'assoc_actor_1', 'inter1', 'actor2', 'assoc_actor_2', 'inter2',
#        'interaction', 'region', 'country', 'admin1', 'admin2', 'admin3',
#        'location', 'latitude', 'longitude', 'geo_precision', 'source',
#        'source_scale', 'notes', 'fatalities', 'timestamp', 'iso3'],
#       dtype='object')

# %% [markdown]
# ### Make a map of some ACLED Data (absolutely use the code from the Global Terrorism Database exercise)

# %%
# Import additional libraries

from bokeh.plotting import figure, output_notebook, show #builds interactive graphs for python
from bokeh.models import Range1d
import math #this is used in graphic section to use the irrational number pi
output_notebook() #Allows inline plotting for Juptyer notebook

#Imports necessary aspects of Bokeh for plotting on a map
from bokeh.tile_providers import get_provider, Vendors
from pyproj import Transformer
tile_provider = get_provider('STAMEN_TERRAIN')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
# syria_res.info()

# %%
# Take the data results from Syria and get the lat/long of the attacks and the type of event
country_map = syria_res[["latitude", 'longitude', 'event_type', 'sub_event_type']]

country_map[['latitude', 'longitude']] = country_map[['latitude', 'longitude']].astype(float)

#see the data this time first 10 rows
country_map.head(10)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#    latitude  longitude                  event_type  \
# 0   36.4726    37.0941  Explosions/Remote violence
# 1   35.6073    36.4645  Explosions/Remote violence
# 2   36.1359    36.7883  Violence against civilians
# 3   36.3837    38.8628      Strategic developments
# 4   35.4066    37.4341                     Battles
# 5   35.3652    37.7886                     Battles
# 6   36.6534    40.3718                    Protests
# 7   35.9428    39.0519                    Protests
# 8   36.5258    37.9510  Explosions/Remote violence
# 9   35.6857    36.3892      Strategic developments
#
#                       sub_event_type
# 0  Shelling/artillery/missile attack
# 1  Shelling/artillery/missile attack
# 2                             Attack
# 3           Change to group/activity
# 4                        Armed clash
# 5                        Armed clash
# 6                   Peaceful protest
# 7                   Peaceful protest
# 8  Shelling/artillery/missile attack
# 9           Change to group/activity

# %%
events_by_type = {} #make an empty datastructure (dictionary) to fill

#This loop goes through each row and counts the number of entries by group
for index, row in country_map.iterrows(): 
    if row["event_type"]  in events_by_type.keys():
        events_by_type[row["event_type"]] += 1 #if group is in the dictionary add 1 attack
    else:
        events_by_type[row["event_type"]] = 1 #add group name to dictionary if not in dictionary

events_by_type
# Out:
# {'Explosions/Remote violence': 52527,
#  'Violence against civilians': 4731,
#  'Strategic developments': 4946,
#  'Battles': 17838,
#  'Protests': 1399,
#  'Riots': 101}

# %%
events = set(country_map.event_type)
events
# Out:
# {'Battles',
#  'Explosions/Remote violence',
#  'Protests',
#  'Riots',
#  'Strategic developments',
#  'Violence against civilians'}

# %%
# Create a new subset of just the battles

batt_all = country_map[country_map.event_type == 'Battles'] 


batt_all.head()
# Out:
#     latitude  longitude event_type sub_event_type
# 4    35.4066    37.4341    Battles    Armed clash
# 5    35.3652    37.7886    Battles    Armed clash
# 14   32.8882    36.0410    Battles    Armed clash
# 15   32.7037    35.9881    Battles    Armed clash
# 16   36.4477    38.8177    Battles    Armed clash

# %%
#make an empty datastructure (dictionary) to fill
batt_by_sub = {} 

#This loop goes through each row and counts the number of entries by group
for index, row in batt_all.iterrows(): 
    if row["sub_event_type"]  in batt_by_sub.keys():
        batt_by_sub[row["sub_event_type"]] += 1 #if sub type is in the dictionary add 1 attack
    else:
        batt_by_sub[row["sub_event_type"]] = 1 #add sub type to dictionary if not in dictionary

batt_by_sub
# Out:
# {'Armed clash': 14284,
#  'Non-state actor overtakes territory': 1768,
#  'Government regains territory': 1786}

# %%
#create pyproj transformer to convert form lat/long to web mercator
transformer = Transformer.from_crs('epsg:4326','epsg:3857')

# %%
map_dict = {} # empty dictionary to track events by lat long
nan_count = {} # some data doesn't have a lat/long so we need to know what we are losing


# Iterate through tables and associate group with lat/long
for idx, row in batt_all.iterrows():    
    if row['sub_event_type'] in map_dict.keys(): 
        if math.isnan(row["latitude"]):
            #This counts no data
            if row['sub_event_type'] in nan_count.keys(): 
                nan_count[row['sub_event_type']] += 1 
            else: 
                nan_count[row['sub_event_type']] = 1
        else: 
            #This has to convert the lat/long to a mercator projection 
            point = transformer.transform(row["latitude"],row["longitude"])
            map_dict[row['sub_event_type']].append([point[0],point[1]]) 
    #BOTH the if an else statement do the same thing but since it is a dictionary one needs to add the group name first
    else:  
        if math.isnan(row["latitude"]):
          nan_count[row['sub_event_type']] = 1
        else: 
            point = transformer.transform(row["latitude"],row["longitude"])
            map_dict[row['sub_event_type']] =[[point[0],point[1]]]
        
#This tells how many attacks we are losing
#nan_count

# %%
# Create the bounding box for Syria

pts = [(38, 34), (32, 43)]
bbox = []
for pt in transformer.itransform(pts): 
    bbox.append(pt)
    
# bbox

# %%
# This creates the data for sub_event_type "Armed Clash"

NPAa_x = []
NPAa_y = []
for pt in map_dict["Armed clash"]:
    NPAa_x.append(pt[0])
    NPAa_y.append(pt[1])

# %%
# This creates the data  for sub_event_type "Non-state actor overtakes territory"

NPAn_x = []
NPAn_y = []
for pt in map_dict["Non-state actor overtakes territory"]:
    NPAn_x.append(pt[0])
    NPAn_y.append(pt[1])

# %%
# This creates the data for sub_event_type "Government regains territory"

NPAg_x = []
NPAg_y = []
for pt in map_dict["Government regains territory"]:
    NPAg_x.append(pt[0])
    NPAg_y.append(pt[1])

# %%
# This plots the data for sub_event_type "Armed Clash"
#Plots the bounding box
p = figure(x_range=(bbox[0][0], bbox[1][0]),y_range=(bbox[0][1], bbox[1][1]),x_axis_type="mercator", y_axis_type="mercator")
#add the map form the Bokeh map vendor in this case Stamen_Terrain --- see documentation
p.add_tile(tile_provider)
# Places a circle for each converted lat/long attack 
p.circle(x = NPAa_x, y = NPAa_y, color= "firebrick")

#shows the plot
show(p)
# Out:
#   <div class="bk-root" id="bf03b6b1-d9a5-4398-aec6-2fe5bb30d5dd" data-root-id="1112"></div>

# %%
# This plots the data  for sub_event_type "Non-state actor overtakes territory"
#Plots the bounding box
p = figure(x_range=(bbox[0][0], bbox[1][0]),y_range=(bbox[0][1], bbox[1][1]),x_axis_type="mercator", y_axis_type="mercator")
#add the map form the Bokeh map vendor in this case Stamen_Terrain --- see documentation
p.add_tile(tile_provider)
# Places a circle for each converted lat/long attack 
p.circle(x = NPAn_x, y = NPAn_y, color= "blue")

#shows the plot
show(p)
# Out:
#   <div class="bk-root" id="50d93443-2c04-4159-9c6b-c0bf24868598" data-root-id="1230"></div>

# %%
# This creates the data for sub_event_type "Government regains territory"
#Plots the bounding box
p = figure(x_range=(bbox[0][0], bbox[1][0]),y_range=(bbox[0][1], bbox[1][1]),x_axis_type="mercator", y_axis_type="mercator")
#add the map form the Bokeh map vendor in this case Stamen_Terrain --- see documentation
p.add_tile(tile_provider)
# Places a circle for each converted lat/long attack 
p.circle(x = NPAg_x, y = NPAg_y, color= "green")

#shows the plot
show(p)
# Out:
#   <div class="bk-root" id="dee33716-9b19-4ff9-a089-effa24db8b4b" data-root-id="1357"></div>

# %%
#This plots all the data for battles in Syria on a single map
#Plots the bounding box
p = figure(x_range=(bbox[0][0], bbox[1][0]),y_range=(bbox[0][1], bbox[1][1]),x_axis_type="mercator", y_axis_type="mercator")
#add the map form the Bokeh map vendor in this case Stamen_Terrain --- see documentation
p.add_tile(tile_provider)
# Places a circle for each converted lat/long attack 
p.circle(x = NPAa_x, y = NPAa_y, color= "firebrick")
p.circle(x = NPAg_x, y = NPAg_y, color= "green")
p.circle(x = NPAn_x, y = NPAn_y, color= "blue")

#shows the plot
show(p)
# Out:
#   <div class="bk-root" id="4c23439b-f045-4e30-9bae-a632d57b1eea" data-root-id="1493"></div>

# %%
# Cheers!
