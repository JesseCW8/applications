# %% [markdown]
# # Dealing with Structured Data- Global Terrorism Database

# %% [markdown]
# ### Thanks to Samuel Capps (6980 2020 QTR 1) for identifying this dynamic

# %%
# Import libraries to aid your analysis
import pandas as pd #pandas places ones data in tables format
from bokeh.plotting import figure, output_notebook, show #builds interactive graphs for python
from bokeh.models import Range1d
import math #this is used in graphic section to use the irrational number pi
output_notebook() #Allows inline plotting for Juptyer notebook
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Let's look at the data

# %%
pwd
# Out:
# '/home/EDSE-jessewte-workspace/MST688/applications'

# %%
# Datasheet was downbloaed form GTD and being read in form a local .csv file
GTD = pd.read_excel(r"/home/EDSE-jessewte-workspace/GTD_db/globalterrorismdb_0919dist.xlsx")
# had some issues with the data types, had to search online for example to read properly
GTD.head() # see the structure--default is first five rows
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaT       58
# 1  197000000002   1970       0     0        NaN         0        NaT      130
# 2  197001000001   1970       1     0        NaN         0        NaT      160
# 3  197001000002   1970       1     0        NaN         0        NaT       78
# 4  197001000003   1970       1     0        NaN         0        NaT      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
# Pandas library has a describe function to apply algorithms against the data...
# whether approriate or not
GTD.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.914640e+05  191464.000000  191464.000000  191464.000000
# mean   2.003486e+11    2003.420136       6.462510      15.507688
# std    1.334949e+09      13.349405       3.388515       8.807727
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991083e+11    1991.000000       4.000000       8.000000
# 50%    2.010031e+11    2010.000000       6.000000      15.000000
# 75%    2.015013e+11    2015.000000       9.000000      23.000000
# max    2.018123e+11    2018.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  191464.000000  191464.000000  191464.000000  186884.000000
# mean        0.047476     131.290446       7.205167      23.462121
# std         0.212656     112.058063       2.923811      18.405309
# min         0.000000       4.000000       1.000000     -53.154613
# 25%         0.000000      78.000000       6.000000      11.274796
# 50%         0.000000      98.000000       7.000000      31.445840
# 75%         0.000000     160.000000      10.000000      34.621521
# max         1.000000    1004.000000      12.000000      74.633553
#
#            longitude    specificity  ...     ransomamt   ransomamtus  \
# count  186883.000000  191463.000000  ...  1.416000e+03  6.230000e+02
# mean       28.902126       1.458172  ...  3.057619e+06  5.227734e+05
# std        57.231040       0.991536  ...  2.951278e+07  6.730057e+06
# min      -176.176447       1.000000  ... -9.900000e+01 -9.900000e+01
# 25%         7.052742       1.000000  ...  0.000000e+00  0.000000e+00
# 50%        43.471427       1.000000  ...  1.500000e+04  0.000000e+00
# 75%        68.783077       1.000000  ...  4.000000e+05  0.000000e+00
# max       179.366667       5.000000  ...  1.000000e+09  1.320000e+08
#
#          ransompaid  ransompaidus  hostkidoutcome     nreleased  \
# count  8.380000e+02    611.000000    12045.000000  11454.000000
# mean   6.961705e+05    217.004910        4.643005    -29.816309
# std    9.792528e+06   2796.042504        2.034429     65.183303
# min   -9.900000e+01    -99.000000        1.000000    -99.000000
# 25%   -9.900000e+01      0.000000        2.000000    -99.000000
# 50%    0.000000e+00      0.000000        4.000000      0.000000
# 75%    1.273412e+03      0.000000        7.000000      1.000000
# max    2.750000e+08  48000.000000        7.000000   2912.000000
#
#              INT_LOG       INT_IDEO       INT_MISC        INT_ANY
# count  191464.000000  191464.000000  191464.000000  191464.000000
# mean       -4.521727      -4.439247       0.088951      -3.930582
# std         4.543713       4.639931       0.556741       4.689726
# min        -9.000000      -9.000000      -9.000000      -9.000000
# 25%        -9.000000      -9.000000       0.000000      -9.000000
# 50%        -9.000000      -9.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
# [8 rows x 77 columns]

# %%
#Identifies the total number of rows
len(GTD)
# Out:
# 191464

# %%
#provides information about the dataframe
GTD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191464 entries, 0 to 191463
# Columns: 135 entries, eventid to related
# dtypes: datetime64[ns](1), float64(53), int64(24), object(57)
# memory usage: 197.2+ MB

# %%
#See the titles of the 135 columns
for col in GTD.columns:
    print(col)
# !!!! Look in the GTD_Codebook to get more information about each column !!!!
# Out:
# eventid
# iyear
# imonth
# iday
# approxdate
# extended
# resolution
# country
# country_txt
# region
# region_txt
# provstate
# city
# latitude
# longitude
# specificity
# vicinity
# location
# summary
# crit1
# crit2
# crit3
# doubtterr
# alternative
# alternative_txt
# multiple
# success
# suicide
# attacktype1
# attacktype1_txt
# attacktype2
# attacktype2_txt
# attacktype3
# attacktype3_txt
# targtype1
# targtype1_txt
# targsubtype1
# targsubtype1_txt
# corp1
# target1
# natlty1
# natlty1_txt
# targtype2
# targtype2_txt
# targsubtype2
# targsubtype2_txt
# corp2
# target2
# natlty2
# natlty2_txt
# targtype3
# targtype3_txt
# targsubtype3
# targsubtype3_txt
# corp3
# target3
# natlty3
# natlty3_txt
# gname
# gsubname
# gname2
# gsubname2
# gname3
# gsubname3
# motive
# guncertain1
# guncertain2
# guncertain3
# individual
# nperps
# nperpcap
# claimed
# claimmode
# claimmode_txt
# claim2
# claimmode2
# claimmode2_txt
# claim3
# claimmode3
# claimmode3_txt
# compclaim
# weaptype1
# weaptype1_txt
# weapsubtype1
# weapsubtype1_txt
# weaptype2
# weaptype2_txt
# weapsubtype2
# weapsubtype2_txt
# weaptype3
# weaptype3_txt
# weapsubtype3
# weapsubtype3_txt
# weaptype4
# weaptype4_txt
# weapsubtype4
# weapsubtype4_txt
# weapdetail
# nkill
# nkillus
# nkillter
# nwound
# nwoundus
# nwoundte
# property
# propextent
# propextent_txt
# propvalue
# propcomment
# ishostkid
# nhostkid
# nhostkidus
# nhours
# ndays
# divert
# kidhijcountry
# ransom
# ransomamt
# ransomamtus
# ransompaid
# ransompaidus
# ransomnote
# hostkidoutcome
# hostkidoutcome_txt
# nreleased
# addnotes
# scite1
# scite2
# scite3
# dbsource
# INT_LOG
# INT_IDEO
# INT_MISC
# INT_ANY
# related

# %%
### PIKE Pike checking which countries are listed in the database
countries = GTD['country_txt'].tolist()
countries = set(countries)
countries
# Out:
# {'Afghanistan',
#  'Albania',
#  'Algeria',
#  'Andorra',
#  'Angola',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia-Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Brunei',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Costa Rica',
#  'Croatia',
#  'Cuba',
#  'Cyprus',
#  'Czech Republic',
#  'Czechoslovakia',
#  'Democratic Republic of the Congo',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'East Germany (GDR)',
#  'East Timor',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Estonia',
#  'Ethiopia',
#  'Falkland Islands',
#  'Fiji',
#  'Finland',
#  'France',
#  'French Guiana',
#  'French Polynesia',
#  'Gabon',
#  'Gambia',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Grenada',
#  'Guadeloupe',
#  'Guatemala',
#  'Guinea',
#  'Guinea-Bissau',
#  'Guyana',
#  'Haiti',
#  'Honduras',
#  'Hong Kong',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'International',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Ivory Coast',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Kosovo',
#  'Kuwait',
#  'Kyrgyzstan',
#  'Laos',
#  'Latvia',
#  'Lebanon',
#  'Lesotho',
#  'Liberia',
#  'Libya',
#  'Lithuania',
#  'Luxembourg',
#  'Macau',
#  'Macedonia',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Maldives',
#  'Mali',
#  'Malta',
#  'Martinique',
#  'Mauritania',
#  'Mauritius',
#  'Mexico',
#  'Moldova',
#  'Montenegro',
#  'Morocco',
#  'Mozambique',
#  'Myanmar',
#  'Namibia',
#  'Nepal',
#  'Netherlands',
#  'New Caledonia',
#  'New Hebrides',
#  'New Zealand',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'North Korea',
#  'North Yemen',
#  'Norway',
#  'Pakistan',
#  'Panama',
#  'Papua New Guinea',
#  'Paraguay',
#  "People's Republic of the Congo",
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Qatar',
#  'Republic of the Congo',
#  'Rhodesia',
#  'Romania',
#  'Russia',
#  'Rwanda',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'Serbia-Montenegro',
#  'Seychelles',
#  'Sierra Leone',
#  'Singapore',
#  'Slovak Republic',
#  'Slovenia',
#  'Solomon Islands',
#  'Somalia',
#  'South Africa',
#  'South Korea',
#  'South Sudan',
#  'South Vietnam',
#  'South Yemen',
#  'Soviet Union',
#  'Spain',
#  'Sri Lanka',
#  'St. Kitts and Nevis',
#  'St. Lucia',
#  'Sudan',
#  'Suriname',
#  'Swaziland',
#  'Sweden',
#  'Switzerland',
#  'Syria',
#  'Taiwan',
#  'Tajikistan',
#  'Tanzania',
#  'Thailand',
#  'Togo',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Turkmenistan',
#  'Uganda',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Uruguay',
#  'Uzbekistan',
#  'Vanuatu',
#  'Vatican City',
#  'Venezuela',
#  'Vietnam',
#  'Wallis and Futuna',
#  'West Bank and Gaza Strip',
#  'West Germany (FRG)',
#  'Western Sahara',
#  'Yemen',
#  'Yugoslavia',
#  'Zaire',
#  'Zambia',
#  'Zimbabwe'}

# %% [markdown]
# # Problem 1: Change the Country (do after going through the whole notebook)

# %%
# reduce the dataframe down to just the philippines
country = GTD[GTD["country_txt"]=="Italy"] # store the information in an object called country
#you can change Philippines to any country in the dataset
country.head(10) #by putting in 10 I changed the default setting of 1st 5 rows to 1st 10 rows
# Out:
#            eventid  iyear  imonth  iday approxdate  extended resolution  \
# 12    197001080001   1970       1     8        NaN         0        NaT
# 97    197003010001   1970       3     1        NaN         0        NaT
# 569   197010240002   1970      10    24        NaN         0        NaT
# 778   197103250001   1971       3    25        NaN         0        NaT
# 986   197108280002   1971       8    28        NaN         0        NaT
# 1021  197109200001   1971       9    20        NaN         0        NaT
# 1261  197205050001   1972       3    15        NaN         0        NaT
# 1423  197208050001   1972       8     5        NaN         0        NaT
# 1433  197208160001   1972       8    16        NaN         0        NaT
# 1648  197212060002   1972      12     6        NaN         0        NaT
#
#       country country_txt  region  ...  \
# 12         98       Italy       8  ...
# 97         98       Italy       8  ...
# 569        98       Italy       8  ...
# 778        98       Italy       8  ...
# 986        98       Italy       8  ...
# 1021       98       Italy       8  ...
# 1261       98       Italy       8  ...
# 1423       98       Italy       8  ...
# 1433       98       Italy       8  ...
# 1648       98       Italy       8  ...
#
#                                                addnotes  \
# 12                                                  NaN
# 97                                                  NaN
# 569                                                 NaN
# 778                                                 NaN
# 986                                                 NaN
# 1021                                                NaN
# 1261  It is not clear if Giangiacomo Feltrinelli was...
# 1423                                                NaN
# 1433                                                NaN
# 1648                                                NaN
#
#                                                  scite1  \
# 12                                                  NaN
# 97                                                  NaN
# 569                                                 NaN
# 778                                                 NaN
# 986                                                 NaN
# 1021                                                NaN
# 1261  Carlo Feltrinelli, "In March 1972, a farmer's ...
# 1423                                                NaN
# 1433                                                NaN
# 1648                                                NaN
#
#                                                  scite2  \
# 12                                                  NaN
# 97                                                  NaN
# 569                                                 NaN
# 778                                                 NaN
# 986                                                 NaN
# 1021                                                NaN
# 1261  Paul Hofman, "Feltrinelli Still a Mystery: Ita...
# 1423                                                NaN
# 1433                                                NaN
# 1648                                                NaN
#
#                                                  scite3  \
# 12                                                  NaN
# 97                                                  NaN
# 569                                                 NaN
# 778                                                 NaN
# 986                                                 NaN
# 1021                                                NaN
# 1261  Paul Hofman, "Feltrinelli Case Takes New Turn:...
# 1423                                                NaN
# 1433                                                NaN
# 1648                                                NaN
#
#                                       dbsource  INT_LOG  INT_IDEO INT_MISC  \
# 12                                Hijacking DB       -9        -9        1
# 97                                        PGIS        1         0        1
# 569                     CBRN Global Chronology       -9        -9        1
# 778                                       PGIS       -9        -9        1
# 986                                       PGIS        0         0        1
# 1021                                      PGIS       -9        -9        1
# 1261  UMD Encyclopedia of World Terrorism 2012       -9        -9        0
# 1423                                      PGIS        1         1        0
# 1433                                      PGIS        1         1        1
# 1648                                      PGIS        1         1        1
#
#      INT_ANY  related
# 12         1      NaN
# 97         1      NaN
# 569        1      NaN
# 778        1      NaN
# 986        1      NaN
# 1021       1      NaN
# 1261      -9      NaN
# 1423       1      NaN
# 1433       1      NaN
# 1648       1      NaN
#
# [10 rows x 135 columns]

# %% [markdown]
# ### Let's deep dive in a country

# %%
attacks_by_group = {} #make an empty datastructure (dictionary) to fill

#This loop goes through each row and counts the number of entries by group
for index, row in country.iterrows(): 
    if row["gname"]  in attacks_by_group.keys():
        attacks_by_group[row["gname"]] += 1 #if group is in the dictionary add 1 attack
    else:
        attacks_by_group[row["gname"]] = 1 #add group name to dictionary if not in dictionary

attacks_by_group
# Out:
# {'Unknown': 678,
#  'Eritrean Liberation Front': 1,
#  'Popular Front for the Liberation of Palestine (PFLP)': 2,
#  'Black September': 5,
#  'Croatian Nationalists': 1,
#  'Armed Proletarian Nuclei (NAP)': 30,
#  'Proletarian Action Group': 1,
#  'Red Brigades': 215,
#  'Black Order': 6,
#  'Baader-Meinhof Group': 22,
#  'Soldiers of the Algerian Opposition': 1,
#  'Armed Communist Struggle': 3,
#  'Armed Communist Formations': 5,
#  'Continuous Struggle': 1,
#  'Combat Territory Groups': 2,
#  'Communist Combat Unit': 2,
#  'Italian Social Movement (MSI)': 17,
#  'Che Guevara Brigade': 5,
#  'Prolitarian Internationalism': 1,
#  'Anti-Zionist Commandos': 3,
#  'Workers Power': 1,
#  'Communist Fighting Unit': 11,
#  'Prima Linea': 58,
#  'Communist Brigade Dante Dimani': 1,
#  'Armed Proletarian Power': 6,
#  'New Partisans Movement': 2,
#  'New Order': 2,
#  'Armed Struggle for Communism': 4,
#  'Communist Brigades': 1,
#  'Armed Squads for Communism': 3,
#  'Combat Brigades': 1,
#  'Revolutionary Action': 7,
#  'Fighters for Communism': 2,
#  'Communist Fighters Group': 1,
#  'Justice Commandos for the Armenian Genocide': 5,
#  'Communist Progress': 2,
#  'Fighting Workers for Communism': 1,
#  'Armed Communist Nucleus': 4,
#  'Combatent Communists': 1,
#  'Communist Fighting Nuclei': 2,
#  'Armed Radical Groups for Communism': 1,
#  'Worker Counterpower': 2,
#  'Proletarian Patrols': 10,
#  'Armed Proletarian Groups for Communism': 4,
#  'Vyborg Brigade': 1,
#  'Territorial Communist Units': 1,
#  'Proletarian Fighting Brigades': 1,
#  'Revolutionary Action Front': 2,
#  'Tonino Micciche Workers Nucleus': 1,
#  'Anti-Government Group': 1,
#  'Organized Proletarian Communists': 3,
#  'Nucleus of the Armed Struggle': 1,
#  'Armed Fighting Nucleus For Communism': 1,
#  'Armed Struggle for Proletarian Power': 1,
#  'Armed Communist Commando': 1,
#  'Fighting Nucleus for Communism': 1,
#  'Communist Armed Nucleus': 1,
#  'Fighting Communist Front': 1,
#  'Combat Nucleus of Communist Unity': 1,
#  'Fighting Proletarian Squads': 13,
#  'Armed Workers Squads': 4,
#  'Armed Nucleus of Communist Workers': 1,
#  'Proletarian Armed Squads': 1,
#  'Armed Proletarian Patrols': 1,
#  'Radical Communist Armed Nucleus': 1,
#  'Armed Commandos in the Fighting Army of Mario Zichieri': 2,
#  'Confederation of Iranian Students/National Union (CISNU)': 1,
#  'Armed Fight for Communism': 4,
#  'Communist Fighting Corunim- Maria Anna Maria': 1,
#  'Worker Autonomy, Continuous Struggle': 3,
#  'Armed Revolutionary Groups': 1,
#  'International Communist Brigade': 1,
#  'Armed Revolutionary Nuclei (NAR)': 20,
#  'Armed Nuclei for Territorial Counterpower': 3,
#  'Southern Nucleus of Communist Counterpower': 1,
#  'Revolutionary Communist Party': 2,
#  'Arab Revolutionary Army': 1,
#  'Communist Fighters Association': 1,
#  'Armed Proletarian Squads': 6,
#  'Aryan Brotherhood': 2,
#  'Autonomous Students': 1,
#  'Anti-Imperialistic Communist Revolutionaries': 2,
#  'Communist Fighting Detachments': 1,
#  'Armed Workers Nuclei': 1,
#  'Armed Womens Nuclei': 1,
#  'Armed Proletarian Group': 1,
#  'Armed Fight for Workers Power': 1,
#  'Fighting Women': 1,
#  'Armed Nuclei for Communism': 2,
#  'Proletarian Nucleus': 1,
#  'Red Flying Squad': 3,
#  'Communist Anti-Imperialistic Revolutionaries': 1,
#  'Armed Proletarian Formations': 1,
#  'Red Army Faction (RAF)': 2,
#  'Proletarian Combatants for Communism': 2,
#  'Communist Attack Brigades': 1,
#  'Armed Anti-Imperialist Movement': 1,
#  'Combatant Nucleus for Communism': 1,
#  'Combatant Communist Front': 1,
#  "Workers' Organization for Communism": 2,
#  'Organized Comrads for Communism': 1,
#  'Guards of the Fighting Proletariat': 1,
#  'Fighting Communist Unit': 1,
#  'Armed Proletariat Fighting Squad': 1,
#  'Communist Territorial Unit': 1,
#  'Organized Comrades for Feminist Counter-Power': 3,
#  'Wild Cats': 1,
#  'Fire Group': 3,
#  'Communists': 6,
#  'Extremists': 1,
#  'Communist Territorial Nuclei': 5,
#  'Proletarian Fighting Patrol': 7,
#  'Red Guerrilla': 1,
#  'Left-Wing Demonstrators': 1,
#  'Communist Nuclei of Counter Power': 1,
#  'Popular Revolutionary Movement (Italy)': 2,
#  'Territorial Communist Command': 1,
#  'Territorial Cells for Boycotting the Elections': 1,
#  'Left-Wing Terrorists': 3,
#  'Fighting Communists': 1,
#  'Tyrolean Defense League': 1,
#  'Italian Extreme Nationalist Organization': 1,
#  'Communist Fighting Front': 1,
#  'Armenian Secret Army for the Liberation of Armenia': 24,
#  'Proletarian Division for the Army of Communist Liberation': 1,
#  'New Armenian Resistance': 3,
#  'Neo-Fascist extremists': 11,
#  'Autonomy (Italy)': 11,
#  'Proletarian communist commandos': 1,
#  'Revolutionary Action Groups': 1,
#  'Territorial Anti-Fascist Patrols': 1,
#  'Anti-Fascist Territorial Group': 2,
#  'Communist Patrols for Counter Power': 2,
#  'Communist Attack Units': 1,
#  'Qaddafi loyalists': 6,
#  'Territorial Armed Groups for Communism': 1,
#  'Armed Groups of Organised Proletariat': 1,
#  'Comrades Organized in Partisan Nuclei': 1,
#  'Iraqi Mujahideen': 1,
#  'Jordanian Masses Organization': 1,
#  'Revolutionary Committee for Counter Force': 1,
#  'Armenian Organization for Armed Struggle': 1,
#  'Tyrol Separatists': 2,
#  'October Third Movement': 1,
#  'Italian Combatents for Alto Adige': 1,
#  'Italians Attacking Policies of the Regional  SVP': 1,
#  'Territorial Patrols of Anti-Fascist Vigilance': 1,
#  'Armenian Guerrillas': 1,
#  'German Speaking Separatists': 3,
#  'International Proletarian Groups': 1,
#  'May 15 Organization for the Liberation of Palestine': 2,
#  'Revolutionary Communist Armed Nuclei': 1,
#  "People's Liberation Movement": 3,
#  'Workers Brigade for Communism': 6,
#  'Communist Nuclear': 1,
#  'Abu Nidal Organization (ANO)': 3,
#  'Communist Group of Proletarian Internationalism': 3,
#  'Shia Muslim extremists': 1,
#  'Front Line Armed Nuclei (FLAN)': 1,
#  'Jewish Armed Resistance': 2,
#  'Communist Front for Counterpower': 2,
#  'Black Lebanon': 1,
#  'Red Brigades Fighting Communist Party (BR-PCC)': 6,
#  'Syrian Battle Front': 1,
#  'Al-Borkan Liberation Organization': 1,
#  'International Communist Group': 2,
#  'Scheutzen group': 1,
#  'Communists Fighting Imperialism and Armaments': 2,
#  'Organization of Mauritanian Nationalists': 1,
#  "Worker's Brigade": 1,
#  'Black September II': 1,
#  'Right-wing extremists': 4,
#  'Islamic Mujahidin': 1,
#  'Revolutionary Organization of Socialist Muslims': 2,
#  'Red Brigades Fighting Communist Union (BR-UCC)': 3,
#  'Armed Communist Front': 1,
#  'Lebanese Terrorist Group': 1,
#  'Anti-Imperialist International Brigades': 2,
#  'Palestinians': 1,
#  'Japanese Red Army (JRA)': 1,
#  "Sudtiroler Volkspartei-south tyrol people's party": 4,
#  'Ein Tyrol (One Tyrol)': 5,
#  'Revolutionary Movement': 1,
#  'Organization of Metropolitan Proletariat and Oppressed Peoples': 1,
#  'Fighting Proletarian Front': 1,
#  'Anarchists': 23,
#  'Continuing Struggle': 1,
#  'Committee for Direct Action Against War': 2,
#  'Communist Guerilla Nuclei': 1,
#  'Armed Falange': 6,
#  'Basque Fatherland and Freedom (ETA)': 15,
#  'Corsican National Liberation Front (FLNC)': 2,
#  'Mafia': 9,
#  'Animal Rights extremists': 2,
#  'Neo-Nazi extremists': 8,
#  'Nucleus of Fighting Communists': 1,
#  'Jewish Extremists': 1,
#  'Nuclei Communist Combattants': 1,
#  'Anonima Sequestri': 1,
#  'Separatists': 1,
#  'Revolutionary Combat Brigades': 1,
#  'Grey Wolves': 4,
#  "Kurdistan Workers' Party (PKK)": 1,
#  'Anti-Racist Guerrilla Nuclei': 1,
#  'Angry Brigade (Italy)': 2,
#  'Anti-Zionist Movement': 2,
#  'Revolutionary Leninist Brigades': 1,
#  'Iconoclasts': 1,
#  'International Solidarity': 2,
#  'Revolutionary Proletarian Initiative Nuclei (NIPR)': 2,
#  'Anti-Imperialist Territorial Nuclei (NTA)': 2,
#  'Sardinian Autonomy Movement': 1,
#  'CCCCC': 4,
#  'Proletarian Nuclei for Communism': 2,
#  'Informal Anarchist Federation': 20,
#  'Moroccan extremists': 1,
#  'Liberation Tigers of Tamil Eelam (LTTE)': 1,
#  'Sisters in Arms': 1,
#  'Conspiracy of Cells of Fire': 1,
#  'Armed Group for the Defence of the People': 2,
#  'Left-wing extremists': 1,
#  'Anarchist Cell Acca (C.A.A.)': 1,
#  'Jihadi-inspired extremists': 2,
#  'Anti-Fascist Activists': 2,
#  'Anti-Semitic extremists': 1,
#  'Cellula Haris Hatzimihelakis/Internazionale nera': 1}

# %%
# Make X and Y axis for a bar chart plotting attacks
groups = list(attacks_by_group.keys())
attacks = list(attacks_by_group.values())

# %%
#Sort from smallest to largest
sorted_groups = sorted(groups, key=lambda x: attacks[groups.index(x)])
sorted_attacks = sorted(attacks)

# sorted_attacks  PIKE Pike: looking over the data
sorted_groups
# Out:
# ['Eritrean Liberation Front',
#  'Croatian Nationalists',
#  'Proletarian Action Group',
#  'Soldiers of the Algerian Opposition',
#  'Continuous Struggle',
#  'Prolitarian Internationalism',
#  'Workers Power',
#  'Communist Brigade Dante Dimani',
#  'Communist Brigades',
#  'Combat Brigades',
#  'Communist Fighters Group',
#  'Fighting Workers for Communism',
#  'Combatent Communists',
#  'Armed Radical Groups for Communism',
#  'Vyborg Brigade',
#  'Territorial Communist Units',
#  'Proletarian Fighting Brigades',
#  'Tonino Micciche Workers Nucleus',
#  'Anti-Government Group',
#  'Nucleus of the Armed Struggle',
#  'Armed Fighting Nucleus For Communism',
#  'Armed Struggle for Proletarian Power',
#  'Armed Communist Commando',
#  'Fighting Nucleus for Communism',
#  'Communist Armed Nucleus',
#  'Fighting Communist Front',
#  'Combat Nucleus of Communist Unity',
#  'Armed Nucleus of Communist Workers',
#  'Proletarian Armed Squads',
#  'Armed Proletarian Patrols',
#  'Radical Communist Armed Nucleus',
#  'Confederation of Iranian Students/National Union (CISNU)',
#  'Communist Fighting Corunim- Maria Anna Maria',
#  'Armed Revolutionary Groups',
#  'International Communist Brigade',
#  'Southern Nucleus of Communist Counterpower',
#  'Arab Revolutionary Army',
#  'Communist Fighters Association',
#  'Autonomous Students',
#  'Communist Fighting Detachments',
#  'Armed Workers Nuclei',
#  'Armed Womens Nuclei',
#  'Armed Proletarian Group',
#  'Armed Fight for Workers Power',
#  'Fighting Women',
#  'Proletarian Nucleus',
#  'Communist Anti-Imperialistic Revolutionaries',
#  'Armed Proletarian Formations',
#  'Communist Attack Brigades',
#  'Armed Anti-Imperialist Movement',
#  'Combatant Nucleus for Communism',
#  'Combatant Communist Front',
#  'Organized Comrads for Communism',
#  'Guards of the Fighting Proletariat',
#  'Fighting Communist Unit',
#  'Armed Proletariat Fighting Squad',
#  'Communist Territorial Unit',
#  'Wild Cats',
#  'Extremists',
#  'Red Guerrilla',
#  'Left-Wing Demonstrators',
#  'Communist Nuclei of Counter Power',
#  'Territorial Communist Command',
#  'Territorial Cells for Boycotting the Elections',
#  'Fighting Communists',
#  'Tyrolean Defense League',
#  'Italian Extreme Nationalist Organization',
#  'Communist Fighting Front',
#  'Proletarian Division for the Army of Communist Liberation',
#  'Proletarian communist commandos',
#  'Revolutionary Action Groups',
#  'Territorial Anti-Fascist Patrols',
#  'Communist Attack Units',
#  'Territorial Armed Groups for Communism',
#  'Armed Groups of Organised Proletariat',
#  'Comrades Organized in Partisan Nuclei',
#  'Iraqi Mujahideen',
#  'Jordanian Masses Organization',
#  'Revolutionary Committee for Counter Force',
#  'Armenian Organization for Armed Struggle',
#  'October Third Movement',
#  'Italian Combatents for Alto Adige',
#  'Italians Attacking Policies of the Regional  SVP',
#  'Territorial Patrols of Anti-Fascist Vigilance',
#  'Armenian Guerrillas',
#  'International Proletarian Groups',
#  'Revolutionary Communist Armed Nuclei',
#  'Communist Nuclear',
#  'Shia Muslim extremists',
#  'Front Line Armed Nuclei (FLAN)',
#  'Black Lebanon',
#  'Syrian Battle Front',
#  'Al-Borkan Liberation Organization',
#  'Scheutzen group',
#  'Organization of Mauritanian Nationalists',
#  "Worker's Brigade",
#  'Black September II',
#  'Islamic Mujahidin',
#  'Armed Communist Front',
#  'Lebanese Terrorist Group',
#  'Palestinians',
#  'Japanese Red Army (JRA)',
#  'Revolutionary Movement',
#  'Organization of Metropolitan Proletariat and Oppressed Peoples',
#  'Fighting Proletarian Front',
#  'Continuing Struggle',
#  'Communist Guerilla Nuclei',
#  'Nucleus of Fighting Communists',
#  'Jewish Extremists',
#  'Nuclei Communist Combattants',
#  'Anonima Sequestri',
#  'Separatists',
#  'Revolutionary Combat Brigades',
#  "Kurdistan Workers' Party (PKK)",
#  'Anti-Racist Guerrilla Nuclei',
#  'Revolutionary Leninist Brigades',
#  'Iconoclasts',
#  'Sardinian Autonomy Movement',
#  'Moroccan extremists',
#  'Liberation Tigers of Tamil Eelam (LTTE)',
#  'Sisters in Arms',
#  'Conspiracy of Cells of Fire',
#  'Left-wing extremists',
#  'Anarchist Cell Acca (C.A.A.)',
#  'Anti-Semitic extremists',
#  'Cellula Haris Hatzimihelakis/Internazionale nera',
#  'Popular Front for the Liberation of Palestine (PFLP)',
#  'Combat Territory Groups',
#  'Communist Combat Unit',
#  'New Partisans Movement',
#  'New Order',
#  'Fighters for Communism',
#  'Communist Progress',
#  'Communist Fighting Nuclei',
#  'Worker Counterpower',
#  'Revolutionary Action Front',
#  'Armed Commandos in the Fighting Army of Mario Zichieri',
#  'Revolutionary Communist Party',
#  'Aryan Brotherhood',
#  'Anti-Imperialistic Communist Revolutionaries',
#  'Armed Nuclei for Communism',
#  'Red Army Faction (RAF)',
#  'Proletarian Combatants for Communism',
#  "Workers' Organization for Communism",
#  'Popular Revolutionary Movement (Italy)',
#  'Anti-Fascist Territorial Group',
#  'Communist Patrols for Counter Power',
#  'Tyrol Separatists',
#  'May 15 Organization for the Liberation of Palestine',
#  'Jewish Armed Resistance',
#  'Communist Front for Counterpower',
#  'International Communist Group',
#  'Communists Fighting Imperialism and Armaments',
#  'Revolutionary Organization of Socialist Muslims',
#  'Anti-Imperialist International Brigades',
#  'Committee for Direct Action Against War',
#  'Corsican National Liberation Front (FLNC)',
#  'Animal Rights extremists',
#  'Angry Brigade (Italy)',
#  'Anti-Zionist Movement',
#  'International Solidarity',
#  'Revolutionary Proletarian Initiative Nuclei (NIPR)',
#  'Anti-Imperialist Territorial Nuclei (NTA)',
#  'Proletarian Nuclei for Communism',
#  'Armed Group for the Defence of the People',
#  'Jihadi-inspired extremists',
#  'Anti-Fascist Activists',
#  'Armed Communist Struggle',
#  'Anti-Zionist Commandos',
#  'Armed Squads for Communism',
#  'Organized Proletarian Communists',
#  'Worker Autonomy, Continuous Struggle',
#  'Armed Nuclei for Territorial Counterpower',
#  'Red Flying Squad',
#  'Organized Comrades for Feminist Counter-Power',
#  'Fire Group',
#  'Left-Wing Terrorists',
#  'New Armenian Resistance',
#  'German Speaking Separatists',
#  "People's Liberation Movement",
#  'Abu Nidal Organization (ANO)',
#  'Communist Group of Proletarian Internationalism',
#  'Red Brigades Fighting Communist Union (BR-UCC)',
#  'Armed Struggle for Communism',
#  'Armed Communist Nucleus',
#  'Armed Proletarian Groups for Communism',
#  'Armed Workers Squads',
#  'Armed Fight for Communism',
#  'Right-wing extremists',
#  "Sudtiroler Volkspartei-south tyrol people's party",
#  'Grey Wolves',
#  'CCCCC',
#  'Black September',
#  'Armed Communist Formations',
#  'Che Guevara Brigade',
#  'Justice Commandos for the Armenian Genocide',
#  'Communist Territorial Nuclei',
#  'Ein Tyrol (One Tyrol)',
#  'Black Order',
#  'Armed Proletarian Power',
#  'Armed Proletarian Squads',
#  'Communists',
#  'Qaddafi loyalists',
#  'Workers Brigade for Communism',
#  'Red Brigades Fighting Communist Party (BR-PCC)',
#  'Armed Falange',
#  'Revolutionary Action',
#  'Proletarian Fighting Patrol',
#  'Neo-Nazi extremists',
#  'Mafia',
#  'Proletarian Patrols',
#  'Communist Fighting Unit',
#  'Neo-Fascist extremists',
#  'Autonomy (Italy)',
#  'Fighting Proletarian Squads',
#  'Basque Fatherland and Freedom (ETA)',
#  'Italian Social Movement (MSI)',
#  'Armed Revolutionary Nuclei (NAR)',
#  'Informal Anarchist Federation',
#  'Baader-Meinhof Group',
#  'Anarchists',
#  'Armenian Secret Army for the Liberation of Armenia',
#  'Armed Proletarian Nuclei (NAP)',
#  'Prima Linea',
#  'Red Brigades',
#  'Unknown']

# %% [markdown]
# # Problem 2: For any country only do plot the top 5 groups (Hint: Use list slicing e.g sorted_attacks[-10:])

# %%
# Uses the bokeh library to plot an interactive graph ---this is very basic view of its capability
# makes the figure
p = figure(x_range = sorted_groups[-5:], plot_width=800, plot_height=1200)
#Plots the data
p.vbar(x=sorted_groups[-5:], width=0.5, bottom=0,
       top= sorted_attacks[-5:], color="firebrick")

p.xaxis.major_label_orientation = math.pi/2  #Rotates the labels on the X axis

# %%
show(p)
# Out:
#   <div class="bk-root" id="778905ca-d7ef-4705-be12-6ca1adc263bc" data-root-id="1243"></div>

# %% [markdown]
# ## Now lets plot the attacks in a map

# %%
#Imports necessary aspects of Bokeh for plotting on a map
from bokeh.tile_providers import get_provider, Vendors
from pyproj import Transformer
tile_provider = get_provider('STAMEN_TERRAIN')

# %%
# Take the data reduced to a country and get the lat/long of the attacks and the name of the group
country_map = country[["latitude", 'longitude', 'gname']]

#see the data this time first 7 rows
country_map.head(7)
# Out:
#        latitude  longitude                                              gname
# 12    41.890961  12.490069                                            Unknown
# 97    41.890961  12.490069                          Eritrean Liberation Front
# 569   41.890961  12.490069                                            Unknown
# 778   45.469212   9.174508                                            Unknown
# 986   41.890961  12.490069  Popular Front for the Liberation of Palestine ...
# 1021  41.890961  12.490069                                            Unknown
# 1261  45.463681   9.188171                                            Unknown

# %%
#create pyproj transformer to convert form lat/long to web mercator
transformer = Transformer.from_crs('epsg:4326','epsg:3857')

# %%
map_dict = {} # empty dictionary to track group attacks by lat long
nan_count = {} # some data doesn't have a lat/long so we need to know what we are losing


# Iterate through tables and associate group with lat/long
for idx, row in country_map.iterrows():    
    if row['gname'] in map_dict.keys(): 
        if math.isnan(row["latitude"]):
            #This counts no data
            if row['gname'] in nan_count.keys(): 
                nan_count[row['gname']] += 1 
            else: 
                nan_count[row['gname']] = 1
        else: 
            #This has to convert the lat/long to a mercator projection 
            point = transformer.transform(row["latitude"],row["longitude"])
            map_dict[row['gname']].append([point[0],point[1]]) 
    #BOTH the if an else statement do the same thing but since it is a dictionary one needs to add the group name first
    else:  
        if math.isnan(row["latitude"]):
          nan_count[row['gname']] = 1
        else: 
            point = transformer.transform(row["latitude"],row["longitude"])
            map_dict[row['gname']] =[[point[0],point[1]]]
        
#This tells how many attacks we are losing
nan_count
# Out:
# {'Unknown': 6,
#  'Prima Linea': 1,
#  'Arab Revolutionary Army': 1,
#  'Red Brigades': 2,
#  'Organization of Metropolitan Proletariat and Oppressed Peoples': 1,
#  'CCCCC': 1}

# %% [markdown]
# # Problem 3: Print the top 5 groups from the map_dict structure

# %%
#sorted_groups
reversed_groups = sorted_groups[::-1]
#print(reversed_groups)
top_5 = reversed_groups[:5]
top_5
# Out:
# ['Unknown',
#  'Red Brigades',
#  'Prima Linea',
#  'Armed Proletarian Nuclei (NAP)',
#  'Armenian Secret Army for the Liberation of Armenia']

# %% [markdown]
# # Problem 4: Change the map to show a new country.
# ## You can get the lat/long for different places here : https://www.latlong.net/

# %%
pts = [(47.6, 6), (36, 19)]
bbox = []
for pt in transformer.itransform(pts): 
    bbox.append(pt)

# %%
NPA_x = []
NPA_y = []
for pt in map_dict["Red Brigades"]:
    NPA_x.append(pt[0])
    NPA_y.append(pt[1])

# %%
#Plots the bounding box
p = figure(x_range=(bbox[0][0], bbox[1][0]),y_range=(bbox[0][1], bbox[1][1]),x_axis_type="mercator", y_axis_type="mercator")
#add the map form the Bokeh map vendor in this case Stamen_Terrain --- see documentation
p.add_tile(tile_provider)
# Places a circle for each converted lat/long attack 
p.circle(x = NPA_x, y = NPA_y, color= "firebrick")

#shows the plot
show(p)
# Out:
#   <div class="bk-root" id="b6c48691-b5c0-4766-8f22-7e613fb57dd7" data-root-id="1360"></div>

# %%
### PIKE Pike making this change and resaving to see if I can commit it this time
